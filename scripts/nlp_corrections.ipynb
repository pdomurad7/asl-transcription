# %%
import spacy
from textblob import TextBlob

# %%
word = "ANOIMALS".lower()

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp(word.lower())
# Out:
# anoimals

# %%
TextBlob(word).correct()
# Out:
# TextBlob("animals")
